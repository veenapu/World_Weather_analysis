# %%
# Import the dependencies
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from citipy import citipy

# Import the random module.
import random

# Import the requests library
import requests

# Import the API key
# ----------NEVER PRINT OR AHARE THE API KEY---------------
from config import weather_api_key

# Import the  time library and the datetime module form teh datetime library
import time
from datetime import datetime

# %%
# Step 3. Create a new set of 2,000 random latitudes and longitudes.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Step 4. Get the nearest city using the citipy module.
# Use the print() function to display the latitude and longitude combinations.
# for coordinate in coordinates:
#     print(citipy.nearest_city(coordinate[0], coordinate[1]).city_name,
#           citipy.nearest_city(coordinate[0], coordinate[1]).country_code)

# %%
# Create a list for holding the cities
cities = []

# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
print(f"The total number of cities is: {len(cities)}")
# Out:
# The total number of cities is: 793

# %%
# Step 5. Perform an API call with the OpenWeatherMap.
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=177bd30dd65b9c531359585c3e1ece81

# %%
# Perform an API call with the OpenWeatherMap.
# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in our list
for i in range(len(cities)):
    
    # Group the cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)
        
    # Create endpoint URL with each city.
    city_url = url + "&q=" + cities[i]

# %%
# Loop through all the cities  in the list:
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        
        # To bypass API limitations, set a timer for 60 seconds
        print("-------------------------------------------------------")
        print(" Waiting for 60 sec....")
        print("-------------------------------------------------------")
        time.sleep(60)
        
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ", "+")
    
    # Log the URL, record, adn set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_weatherdescription = city_weather["weather"][0]["description"]
        
        # Convert the date to ISO standard.
        #city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Weather Description":city_weatherdescription})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")

print(f"Total number of cities pulled from the API: {len(city_data)}")
# Out:
# Processing Record 1 of Set 16 | norman wells
# Processing Record 2 of Set 16 | hermanus
# Processing Record 3 of Set 16 | butaritari
# Processing Record 4 of Set 16 | sabzevar
# Processing Record 5 of Set 16 | tsihombe
# City not found. Skipping...
# Processing Record 6 of Set 16 | grindavik
# Processing Record 7 of Set 16 | narsaq
# Processing Record 8 of Set 16 | barentsburg
# City not found. Skipping...
# Processing Record 9 of Set 16 | pisco
# Processing Record 10 of Set 16 | leirvik
# Processing Record 11 of Set 16 | shellbrook
# Processing Record 12 of Set 16 | bathsheba
# Processing Record 13 of Set 16 | saskylakh
# Processing Record 14 of Set 16 | olgina
# Processing Record 15 of Set 16 | te anau
# Processing Record 16 of Set 16 | linchuan
# City not found. Skipping...
# Processing Record 17 of Set 16 | busselton
# Processing Record 18 of Set 16 | inhambane
# Processing Record 19 of Set 16 | new norfolk
# Processing Record 20 of Set 16 | georgetown
# Processing Record 21 of Set 16 | sao paulo de olivenca
# Processing Record 22 of Set 16 | rikitea
# Processing Record 23 of Set 16 | coracao de jesus
# Processing Record 24 of Set 16 | east london
# Processing Record 25 of Set 16 | jamestown
# Processing Record 26 of Set 16 | kapaa
# Processing Record 27 of Set 16 | maghama
# City not found. Skipping...
# Processing Record 28 of Set 16 | bluff
# Processing Record 29 of Set 16 | pangai
# Processing Record 30 of Set 16 | yambio
# Processing Record 31 of Set 16 | cherskiy
# Processing Record 32 of Set 16 | tulum
# Processing Record 33 of Set 16 | fethiye
# Processing Record 34 of Set 16 | sakaraha
# Processing Record 35 of Set 16 | hithadhoo
# Processing Record 36 of Set 16 | nikolskoye
# Processing Record 37 of Set 16 | burkhala
# City not found. Skipping...
# Processing Record 38 of Set 16 | ushuaia
# Processing Record 39 of Set 16 | lebu
# Processing Record 40 of Set 16 | nioro
# Processing Record 41 of Set 16 | nyurba
# Processing Record 42 of Set 16 | kaitangata
# Processing Record 43 of Set 16 | severo-kurilsk
# Processing Record 44 of Set 16 | dunedin
# Processing Record 45 of Set 16 | broome
# Processing Record 46 of Set 16 | aleksandrov gay
# Processing Record 47 of Set 16 | bredasdorp
# Processing Record 48 of Set 16 | phan rang
# City not found. Skipping...
# Processing Record 49 of Set 16 | tukrah
# Processing Record 50 of Set 16 | udalguri
# -------------------------------------------------------
#  Waiting for 60 sec....
# -------------------------------------------------------
# Processing Record 1 of Set 17 | ahipara
# Processing Record 2 of Set 17 | udachnyy
# Processing Record 3 of Set 17 | waingapu
# Processing Record 4 of Set 17 | angangueo
# Processing Record 5 of Set 17 | jertih
# Processing Record 6 of Set 17 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 7 of Set 17 | houma
# Processing Record 8 of Set 17 | mataura
# Processing Record 9 of Set 17 | beloha
# Processing Record 10 of Set 17 | amderma
# City not found. Skipping...
# Processing Record 11 of Set 17 | petropavlovsk-kamchatskiy
# Processing Record 12 of Set 17 | khasan
# Processing Record 13 of Set 17 | ponta delgada
# Processing Record 14 of Set 17 | yellowknife
# Processing Record 15 of Set 17 | coahuayana
# Processing Record 16 of Set 17 | castro
# Processing Record 17 of Set 17 | saldanha
# Processing Record 18 of Set 17 | ellsworth
# Processing Record 19 of Set 17 | portobelo
# Processing Record 20 of Set 17 | nelson bay
# Processing Record 21 of Set 17 | aracati
# Processing Record 22 of Set 17 | lagoa
# Processing Record 23 of Set 17 | starkville
# Processing Record 24 of Set 17 | sur
# Processing Record 25 of Set 17 | husavik
# Processing Record 26 of Set 17 | benguela
# Processing Record 27 of Set 17 | tivaouane
# Processing Record 28 of Set 17 | taolanaro
# City not found. Skipping...
# Processing Record 29 of Set 17 | ribeira grande
# Processing Record 30 of Set 17 | klaksvik
# Processing Record 31 of Set 17 | yaan
# Processing Record 32 of Set 17 | tadine
# Processing Record 33 of Set 17 | punta arenas
# Processing Record 34 of Set 17 | solnechnyy
# Processing Record 35 of Set 17 | barrow
# Processing Record 36 of Set 17 | bargi
# Processing Record 37 of Set 17 | benghazi
# Processing Record 38 of Set 17 | belushya guba
# City not found. Skipping...
# Processing Record 39 of Set 17 | tuktoyaktuk
# Processing Record 40 of Set 17 | rawson
# Processing Record 41 of Set 17 | sola
# Processing Record 42 of Set 17 | gold coast
# Processing Record 43 of Set 17 | agadez
# Processing Record 44 of Set 17 | kodiak
# Processing Record 45 of Set 17 | albion
# Processing Record 46 of Set 17 | bethel
# Processing Record 47 of Set 17 | bengkulu
# Processing Record 48 of Set 17 | gat
# Processing Record 49 of Set 17 | puerto ayora
# Processing Record 50 of Set 17 | tra vinh
# -------------------------------------------------------
#  Waiting for 60 sec....
# -------------------------------------------------------
# Processing Record 1 of Set 18 | nizhneyansk
# City not found. Skipping...
# Processing Record 2 of Set 18 | avarua
# Processing Record 3 of Set 18 | geraldton
# Processing Record 4 of Set 18 | prado
# Processing Record 5 of Set 18 | cabo san lucas
# Processing Record 6 of Set 18 | naze
# Processing Record 7 of Set 18 | jalu
# Processing Record 8 of Set 18 | cairns
# Processing Record 9 of Set 18 | lorengau
# Processing Record 10 of Set 18 | pangkalanbuun
# Processing Record 11 of Set 18 | dekar
# Processing Record 12 of Set 18 | paulo afonso
# Processing Record 13 of Set 18 | bolshoy lug
# Processing Record 14 of Set 18 | port hardy
# Processing Record 15 of Set 18 | camacupa
# Processing Record 16 of Set 18 | albany
# Processing Record 17 of Set 18 | candawaga
# City not found. Skipping...
# Processing Record 18 of Set 18 | cape town
# Processing Record 19 of Set 18 | asuncion
# Processing Record 20 of Set 18 | unecha
# Processing Record 21 of Set 18 | yerbogachen
# Processing Record 22 of Set 18 | pemangkat
# Processing Record 23 of Set 18 | carnarvon
# Processing Record 24 of Set 18 | saravan
# Processing Record 25 of Set 18 | hilo
# Processing Record 26 of Set 18 | ponta do sol
# Processing Record 27 of Set 18 | lahat
# Processing Record 28 of Set 18 | manjacaze
# Processing Record 29 of Set 18 | tombouctou
# Processing Record 30 of Set 18 | chegutu
# Processing Record 31 of Set 18 | bambous virieux
# Processing Record 32 of Set 18 | axim
# Processing Record 33 of Set 18 | quang ngai
# Processing Record 34 of Set 18 | kahului
# Processing Record 35 of Set 18 | port alfred
# Processing Record 36 of Set 18 | mama
# Processing Record 37 of Set 18 | urumqi
# Processing Record 38 of Set 18 | chuy
# Processing Record 39 of Set 18 | vaini
# Processing Record 40 of Set 18 | ngawen
# Processing Record 41 of Set 18 | port lincoln
# Processing Record 42 of Set 18 | energetik
# Processing Record 43 of Set 18 | pitimbu
# Processing Record 44 of Set 18 | nha trang
# Processing Record 45 of Set 18 | hobart
# Processing Record 46 of Set 18 | abu samrah
# Processing Record 47 of Set 18 | torbay
# Processing Record 48 of Set 18 | omaruru
# Processing Record 49 of Set 18 | kruisfontein
# Processing Record 50 of Set 18 | ketchikan
# -------------------------------------------------------
#  Waiting for 60 sec....
# -------------------------------------------------------
# Processing Record 1 of Set 19 | kampot
# Processing Record 2 of Set 19 | saint-philippe
# Processing Record 3 of Set 19 | qaanaaq
# Processing Record 4 of Set 19 | atuona
# Processing Record 5 of Set 19 | longyearbyen
# Processing Record 6 of Set 19 | esperance
# Processing Record 7 of Set 19 | santa vitoria do palmar
# Processing Record 8 of Set 19 | basco
# Processing Record 9 of Set 19 | meulaboh
# Processing Record 10 of Set 19 | high level
# Processing Record 11 of Set 19 | conceicao do araguaia
# Processing Record 12 of Set 19 | ancud
# Processing Record 13 of Set 19 | barbar
# City not found. Skipping...
# Processing Record 14 of Set 19 | itarema
# Processing Record 15 of Set 19 | inderborskiy
# City not found. Skipping...
# Processing Record 16 of Set 19 | dolores
# Processing Record 17 of Set 19 | tarakan
# Processing Record 18 of Set 19 | flinders
# Processing Record 19 of Set 19 | mogadishu
# Processing Record 20 of Set 19 | andrews
# Processing Record 21 of Set 19 | san patricio
# Processing Record 22 of Set 19 | margate
# Processing Record 23 of Set 19 | upernavik
# Processing Record 24 of Set 19 | karoi
# Processing Record 25 of Set 19 | hilton head island
# Processing Record 26 of Set 19 | bolungarvik
# City not found. Skipping...
# Processing Record 27 of Set 19 | porbandar
# Processing Record 28 of Set 19 | kuala krai
# City not found. Skipping...
# Processing Record 29 of Set 19 | sinnamary
# Processing Record 30 of Set 19 | luwuk
# Processing Record 31 of Set 19 | westerland
# Processing Record 32 of Set 19 | mahebourg
# Processing Record 33 of Set 19 | thompson
# Processing Record 34 of Set 19 | tezu
# Processing Record 35 of Set 19 | abadan
# Processing Record 36 of Set 19 | kudahuvadhoo
# Processing Record 37 of Set 19 | luderitz
# Processing Record 38 of Set 19 | nynashamn
# Processing Record 39 of Set 19 | belgrade
# Processing Record 40 of Set 19 | mar del plata
# Processing Record 41 of Set 19 | chabahar
# Processing Record 42 of Set 19 | port-gentil
# Processing Record 43 of Set 19 | khatanga
# Processing Record 44 of Set 19 | jega
# Processing Record 45 of Set 19 | aklavik
# Processing Record 46 of Set 19 | aksay
# Processing Record 47 of Set 19 | hofn
# Processing Record 48 of Set 19 | athens
# Processing Record 49 of Set 19 | tumannyy
# City not found. Skipping...
# Processing Record 50 of Set 19 | airai
# -------------------------------------------------------
#  Waiting for 60 sec....
# -------------------------------------------------------
# Processing Record 1 of Set 20 | banihal
# Processing Record 2 of Set 20 | lufilufi
# Processing Record 3 of Set 20 | peruibe
# Processing Record 4 of Set 20 | loanda
# Processing Record 5 of Set 20 | cayenne
# Processing Record 6 of Set 20 | vila velha
# Processing Record 7 of Set 20 | hamilton
# Processing Record 8 of Set 20 | berezovyy
# Processing Record 9 of Set 20 | hinton
# Processing Record 10 of Set 20 | makinsk
# Processing Record 11 of Set 20 | namibe
# Processing Record 12 of Set 20 | leningradskiy
# Processing Record 13 of Set 20 | beian
# Processing Record 14 of Set 20 | talnakh
# Processing Record 15 of Set 20 | antofagasta
# Processing Record 16 of Set 20 | zhangjiakou
# Processing Record 17 of Set 20 | amparafaravola
# Processing Record 18 of Set 20 | neyshabur
# Processing Record 19 of Set 20 | mercedes
# Processing Record 20 of Set 20 | northam
# Processing Record 21 of Set 20 | asyut
# Processing Record 22 of Set 20 | surgut
# Processing Record 23 of Set 20 | ngunguru
# Processing Record 24 of Set 20 | hildburghausen
# Processing Record 25 of Set 20 | hasaki
# Processing Record 26 of Set 20 | luba
# Processing Record 27 of Set 20 | lompoc
# Processing Record 28 of Set 20 | angoram
# Processing Record 29 of Set 20 | sumter
# Processing Record 30 of Set 20 | japura
# Processing Record 31 of Set 20 | jishui
# Processing Record 32 of Set 20 | ko samui
# Processing Record 33 of Set 20 | hami
# Processing Record 34 of Set 20 | rocha
# Processing Record 35 of Set 20 | halifax
# Processing Record 36 of Set 20 | tasiilaq
# Processing Record 37 of Set 20 | yar-sale
# Processing Record 38 of Set 20 | kawana waters
# City not found. Skipping...
# Processing Record 39 of Set 20 | nishihara
# Processing Record 40 of Set 20 | constitucion
# Processing Record 41 of Set 20 | kalisz
# Processing Record 42 of Set 20 | samarai
# Processing Record 43 of Set 20 | chokurdakh
# Processing Record 44 of Set 20 | jumilla
# Processing Record 45 of Set 20 | honningsvag
# Processing Record 46 of Set 20 | vestbygda
# City not found. Skipping...
# Processing Record 47 of Set 20 | acandi
# Processing Record 48 of Set 20 | ust-kan
# Processing Record 49 of Set 20 | saleaula
# City not found. Skipping...
# Processing Record 50 of Set 20 | harper
# -------------------------------------------------------
#  Waiting for 60 sec....
# -------------------------------------------------------
# Processing Record 1 of Set 21 | erzin
# Processing Record 2 of Set 21 | umm lajj
# Processing Record 3 of Set 21 | comodoro rivadavia
# Processing Record 4 of Set 21 | iberia
# Processing Record 5 of Set 21 | mys shmidta
# City not found. Skipping...
# Processing Record 6 of Set 21 | bud
# Processing Record 7 of Set 21 | hualmay
# Processing Record 8 of Set 21 | igrim
# Processing Record 9 of Set 21 | attawapiskat
# City not found. Skipping...
# Processing Record 10 of Set 21 | kuche
# City not found. Skipping...
# Processing Record 11 of Set 21 | faya
# Processing Record 12 of Set 21 | dinguiraye
# Processing Record 13 of Set 21 | tornio
# Processing Record 14 of Set 21 | turtkul
# City not found. Skipping...
# Processing Record 15 of Set 21 | chimoio
# Processing Record 16 of Set 21 | trapani
# Processing Record 17 of Set 21 | fraga
# Processing Record 18 of Set 21 | garhi yasin
# Processing Record 19 of Set 21 | middle island
# Processing Record 20 of Set 21 | kurilsk
# Processing Record 21 of Set 21 | salta
# Processing Record 22 of Set 21 | isangel
# Processing Record 23 of Set 21 | staryy nadym
# Processing Record 24 of Set 21 | guangyuan
# Processing Record 25 of Set 21 | innisfail
# Processing Record 26 of Set 21 | wanning
# Processing Record 27 of Set 21 | fortuna
# Processing Record 28 of Set 21 | olafsvik
# Processing Record 29 of Set 21 | souillac
# Processing Record 30 of Set 21 | korablino
# Processing Record 31 of Set 21 | la ronge
# Processing Record 32 of Set 21 | mehamn
# Processing Record 33 of Set 21 | manokwari
# Processing Record 34 of Set 21 | joshimath
# Processing Record 35 of Set 21 | burayevo
# Processing Record 36 of Set 21 | bodden town
# Processing Record 37 of Set 21 | palmas bellas
# Processing Record 38 of Set 21 | dikson
# Processing Record 39 of Set 21 | dargaville
# Processing Record 40 of Set 21 | port moresby
# Processing Record 41 of Set 21 | kirakira
# Processing Record 42 of Set 21 | porosozero
# Processing Record 43 of Set 21 | batsfjord
# Processing Record 44 of Set 21 | talara
# Processing Record 45 of Set 21 | carballo
# Processing Record 46 of Set 21 | provideniya
# Processing Record 47 of Set 21 | locri
# Processing Record 48 of Set 21 | khandyga
# Processing Record 49 of Set 21 | tabou
# Processing Record 50 of Set 21 | atar
# -------------------------------------------------------
#  Waiting for 60 sec....
# -------------------------------------------------------
# Processing Record 1 of Set 22 | cap-aux-meules
# Processing Record 2 of Set 22 | zhireken
# Processing Record 3 of Set 22 | codrington
# Processing Record 4 of Set 22 | sitka
# Processing Record 5 of Set 22 | vardo
# Processing Record 6 of Set 22 | wajir
# Processing Record 7 of Set 22 | mount isa
# Processing Record 8 of Set 22 | langsa
# Processing Record 9 of Set 22 | laguna
# Processing Record 10 of Set 22 | chenghai
# Processing Record 11 of Set 22 | teixoso
# Processing Record 12 of Set 22 | haicheng
# Processing Record 13 of Set 22 | clyde river
# Processing Record 14 of Set 22 | port elizabeth
# Processing Record 15 of Set 22 | zolotinka
# City not found. Skipping...
# Processing Record 16 of Set 22 | sembe
# Processing Record 17 of Set 22 | srednekolymsk
# Processing Record 18 of Set 22 | vaitape
# Processing Record 19 of Set 22 | ha noi
# Processing Record 20 of Set 22 | vanimo
# Processing Record 21 of Set 22 | nizhniy kuranakh
# Processing Record 22 of Set 22 | balikpapan
# Processing Record 23 of Set 22 | awbari
# Processing Record 24 of Set 22 | tabiauea
# City not found. Skipping...
# Processing Record 25 of Set 22 | shingu
# Processing Record 26 of Set 22 | kyotera
# Processing Record 27 of Set 22 | erenhot
# Processing Record 28 of Set 22 | arraial do cabo
# Processing Record 29 of Set 22 | menongue
# Processing Record 30 of Set 22 | suzu
# City not found. Skipping...
# Processing Record 31 of Set 22 | umm kaddadah
# Processing Record 32 of Set 22 | sibolga
# Processing Record 33 of Set 22 | abu dhabi
# Processing Record 34 of Set 22 | ambilobe
# Processing Record 35 of Set 22 | mus
# Processing Record 36 of Set 22 | namatanai
# Processing Record 37 of Set 22 | champoton
# Processing Record 38 of Set 22 | viligili
# City not found. Skipping...
# Processing Record 39 of Set 22 | saint george
# Processing Record 40 of Set 22 | kulhudhuffushi
# Processing Record 41 of Set 22 | coquimbo
# Processing Record 42 of Set 22 | nanortalik
# Processing Record 43 of Set 22 | klichka
# Processing Record 44 of Set 22 | aranda de duero
# Processing Record 45 of Set 22 | shenjiamen
# Processing Record 46 of Set 22 | ostrovnoy
# Processing Record 47 of Set 22 | richards bay
# Processing Record 48 of Set 22 | cuauhtemoc
# Processing Record 49 of Set 22 | ksenyevka
# City not found. Skipping...
# Processing Record 50 of Set 22 | tamworth
# -------------------------------------------------------
#  Waiting for 60 sec....
# -------------------------------------------------------
# Processing Record 1 of Set 23 | cidreira
# Processing Record 2 of Set 23 | kasongo-lunda
# Processing Record 3 of Set 23 | omboue
# Processing Record 4 of Set 23 | sept-iles
# Processing Record 5 of Set 23 | at-bashi
# Processing Record 6 of Set 23 | darab
# Processing Record 7 of Set 23 | champerico
# Processing Record 8 of Set 23 | general pico
# Processing Record 9 of Set 23 | ilulissat
# Processing Record 10 of Set 23 | disna
# Processing Record 11 of Set 23 | camana
# Processing Record 12 of Set 23 | udaipura
# Processing Record 13 of Set 23 | katsuura
# Processing Record 14 of Set 23 | tiksi
# Processing Record 15 of Set 23 | portland
# Processing Record 16 of Set 23 | naryan-mar
# Processing Record 17 of Set 23 | gayeri
# Processing Record 18 of Set 23 | bambanglipuro
# Processing Record 19 of Set 23 | keffi
# Processing Record 20 of Set 23 | asau
# Processing Record 21 of Set 23 | saint-joseph
# Processing Record 22 of Set 23 | haines junction
# Processing Record 23 of Set 23 | henties bay
# Processing Record 24 of Set 23 | srivardhan
# Processing Record 25 of Set 23 | avera
# Processing Record 26 of Set 23 | kuching
# Processing Record 27 of Set 23 | esso
# Processing Record 28 of Set 23 | saint-pierre
# Processing Record 29 of Set 23 | asosa
# Processing Record 30 of Set 23 | cabedelo
# Processing Record 31 of Set 23 | iqaluit
# Processing Record 32 of Set 23 | vryheid
# Processing Record 33 of Set 23 | brawley
# Processing Record 34 of Set 23 | plettenberg bay
# Processing Record 35 of Set 23 | sombrio
# Processing Record 36 of Set 23 | lolua
# City not found. Skipping...
# Processing Record 37 of Set 23 | roxana
# Processing Record 38 of Set 23 | jining
# Processing Record 39 of Set 23 | mayo
# Processing Record 40 of Set 23 | soyo
# Processing Record 41 of Set 23 | nakhon thai
# Processing Record 42 of Set 23 | alice springs
# Processing Record 43 of Set 23 | barawe
# City not found. Skipping...
# Processing Record 44 of Set 23 | aguadilla
# Processing Record 45 of Set 23 | kiruna
# Processing Record 46 of Set 23 | wa
# City not found. Skipping...
# Processing Record 47 of Set 23 | ust-kuyga
# Processing Record 48 of Set 23 | rurrenabaque
# Processing Record 49 of Set 23 | poyarkovo
# Processing Record 50 of Set 23 | lusambo
# -------------------------------------------------------
#  Waiting for 60 sec....
# -------------------------------------------------------
# Processing Record 1 of Set 24 | puerto escondido
# Processing Record 2 of Set 24 | barcelos
# Processing Record 3 of Set 24 | terre-de-bas
# Processing Record 4 of Set 24 | ust-kulom
# Processing Record 5 of Set 24 | oranjestad
# Processing Record 6 of Set 24 | arlit
# Processing Record 7 of Set 24 | kongolo
# Processing Record 8 of Set 24 | jiddah
# City not found. Skipping...
# Processing Record 9 of Set 24 | san quintin
# Processing Record 10 of Set 24 | sibu
# Processing Record 11 of Set 24 | ryotsu
# Processing Record 12 of Set 24 | tabukiniberu
# City not found. Skipping...
# Processing Record 13 of Set 24 | zharkent
# Processing Record 14 of Set 24 | yugo-kamskiy
# Processing Record 15 of Set 24 | nabire
# Processing Record 16 of Set 24 | seymchan
# Processing Record 17 of Set 24 | zabaykalsk
# Processing Record 18 of Set 24 | roros
# Processing Record 19 of Set 24 | nola
# Processing Record 20 of Set 24 | jalapa
# Processing Record 21 of Set 24 | san pedro
# Processing Record 22 of Set 24 | qaqortoq
# Processing Record 23 of Set 24 | cap malheureux
# Processing Record 24 of Set 24 | sentyabrskiy
# City not found. Skipping...
# Processing Record 25 of Set 24 | arica
# Processing Record 26 of Set 24 | dustlik
# Processing Record 27 of Set 24 | inuvik
# Processing Record 28 of Set 24 | jumla
# Processing Record 29 of Set 24 | ajdabiya
# Processing Record 30 of Set 24 | chunskiy
# Processing Record 31 of Set 24 | oranjemund
# Processing Record 32 of Set 24 | west wendover
# Processing Record 33 of Set 24 | canutama
# Processing Record 34 of Set 24 | labuhan
# Processing Record 35 of Set 24 | celestun
# Processing Record 36 of Set 24 | kem
# Processing Record 37 of Set 24 | kavieng
# Processing Record 38 of Set 24 | aripuana
# Processing Record 39 of Set 24 | mahon
# Processing Record 40 of Set 24 | groton
# Processing Record 41 of Set 24 | vaitupu
# City not found. Skipping...
# Processing Record 42 of Set 24 | bongandanga
# Processing Record 43 of Set 24 | koslan
# Processing Record 44 of Set 24 | hobyo
# Processing Record 45 of Set 24 | florissant
# Processing Record 46 of Set 24 | port-cartier
# Processing Record 47 of Set 24 | afikpo
# Processing Record 48 of Set 24 | matagami
# Processing Record 49 of Set 24 | agbor
# Processing Record 50 of Set 24 | half moon bay
# -------------------------------------------------------
#  Waiting for 60 sec....
# -------------------------------------------------------
# Processing Record 1 of Set 25 | zhanatas
# City not found. Skipping...
# Processing Record 2 of Set 25 | lagos
# Processing Record 3 of Set 25 | berezniki
# Processing Record 4 of Set 25 | mount gambier
# Processing Record 5 of Set 25 | karratha
# Processing Record 6 of Set 25 | alofi
# Processing Record 7 of Set 25 | argelia
# Processing Record 8 of Set 25 | babu
# Processing Record 9 of Set 25 | quatre cocos
# Processing Record 10 of Set 25 | victoria
# Processing Record 11 of Set 25 | contramaestre
# Processing Record 12 of Set 25 | coihaique
# Processing Record 13 of Set 25 | tres picos
# Processing Record 14 of Set 25 | porto nacional
# Processing Record 15 of Set 25 | marawi
# Processing Record 16 of Set 25 | soller
# Processing Record 17 of Set 25 | chapleau
# Processing Record 18 of Set 25 | krasnoye-na-volge
# Processing Record 19 of Set 25 | adrar
# Processing Record 20 of Set 25 | bolshoy tsaryn
# City not found. Skipping...
# Processing Record 21 of Set 25 | tura
# Processing Record 22 of Set 25 | koumac
# Processing Record 23 of Set 25 | strathpeffer
# Processing Record 24 of Set 25 | lilongwe
# Processing Record 25 of Set 25 | kysyl-syr
# Processing Record 26 of Set 25 | sanmenxia
# Processing Record 27 of Set 25 | viedma
# Processing Record 28 of Set 25 | san vicente
# Processing Record 29 of Set 25 | mwinilunga
# Processing Record 30 of Set 25 | sompeta
# Processing Record 31 of Set 25 | abu kamal
# Processing Record 32 of Set 25 | marzuq
# Processing Record 33 of Set 25 | marsabit
# Processing Record 34 of Set 25 | college
# Processing Record 35 of Set 25 | airdrie
# Processing Record 36 of Set 25 | makakilo city
# Processing Record 37 of Set 25 | severnoye
# Processing Record 38 of Set 25 | sao joao da barra
# Processing Record 39 of Set 25 | eureka
# Processing Record 40 of Set 25 | kazalinsk
# City not found. Skipping...
# Processing Record 41 of Set 25 | verkhnyaya inta
# Processing Record 42 of Set 25 | erie
# Processing Record 43 of Set 25 | zhezkazgan
# Processing Record 44 of Set 25 | buala
# Processing Record 45 of Set 25 | shache
# Processing Record 46 of Set 25 | sambo creek
# Processing Record 47 of Set 25 | tuatapere
# Processing Record 48 of Set 25 | rawannawi
# City not found. Skipping...
# Processing Record 49 of Set 25 | aykhal
# Processing Record 50 of Set 25 | leticia
# -------------------------------------------------------
#  Waiting for 60 sec....
# -------------------------------------------------------
# Processing Record 1 of Set 26 | bay roberts
# Processing Record 2 of Set 26 | grand river south east
# City not found. Skipping...
# Processing Record 3 of Set 26 | acapulco
# Processing Record 4 of Set 26 | hambantota
# Processing Record 5 of Set 26 | los llanos de aridane
# Processing Record 6 of Set 26 | severo-yeniseyskiy
# Processing Record 7 of Set 26 | shimoda
# Processing Record 8 of Set 26 | taltal
# Processing Record 9 of Set 26 | louisbourg
# City not found. Skipping...
# Processing Record 10 of Set 26 | aksu
# Processing Record 11 of Set 26 | paamiut
# Processing Record 12 of Set 26 | tommot
# Processing Record 13 of Set 26 | escarcega
# Processing Record 14 of Set 26 | raudeberg
# Processing Record 15 of Set 26 | martapura
# Processing Record 16 of Set 26 | samusu
# City not found. Skipping...
# Processing Record 17 of Set 26 | toppenish
# Processing Record 18 of Set 26 | whitehorse
# Processing Record 19 of Set 26 | saint anthony
# Processing Record 20 of Set 26 | dolinsk
# Processing Record 21 of Set 26 | halalo
# City not found. Skipping...
# Processing Record 22 of Set 26 | aasiaat
# Processing Record 23 of Set 26 | banepa
# Processing Record 24 of Set 26 | dzhusaly
# City not found. Skipping...
# Processing Record 25 of Set 26 | brae
# Processing Record 26 of Set 26 | agadir
# Processing Record 27 of Set 26 | itaituba
# Processing Record 28 of Set 26 | susanville
# Processing Record 29 of Set 26 | valley
# Processing Record 30 of Set 26 | morros
# Processing Record 31 of Set 26 | oksfjord
# Processing Record 32 of Set 26 | sobolevo
# Processing Record 33 of Set 26 | colquechaca
# Processing Record 34 of Set 26 | dabat
# Processing Record 35 of Set 26 | kashan
# Processing Record 36 of Set 26 | lahaina
# Processing Record 37 of Set 26 | sehithwa
# Processing Record 38 of Set 26 | meyungs
# City not found. Skipping...
# Processing Record 39 of Set 26 | borujan
# City not found. Skipping...
# Processing Record 40 of Set 26 | kismayo
# Processing Record 41 of Set 26 | almaznyy
# Processing Record 42 of Set 26 | tigil
# Processing Record 43 of Set 26 | rockland
# Processing Record 44 of Set 26 | butembo
# Processing Record 45 of Set 26 | pak phanang
# Processing Record 46 of Set 26 | progreso
# Processing Record 47 of Set 26 | goderich
# Processing Record 48 of Set 26 | sechelt
# Processing Record 49 of Set 26 | wulanhaote
# City not found. Skipping...
# Processing Record 50 of Set 26 | andros town
# -------------------------------------------------------
#  Waiting for 60 sec....
# -------------------------------------------------------
# Processing Record 1 of Set 27 | constantine
# Processing Record 2 of Set 27 | kjollefjord
# Processing Record 3 of Set 27 | nakusp
# Processing Record 4 of Set 27 | natal
# Processing Record 5 of Set 27 | warrnambool
# Processing Record 6 of Set 27 | bonthe
# Processing Record 7 of Set 27 | touros
# Processing Record 8 of Set 27 | cihuatlan
# Processing Record 9 of Set 27 | kodinsk
# Processing Record 10 of Set 27 | bonavista
# Processing Record 11 of Set 27 | chemal
# Processing Record 12 of Set 27 | kisangani
# Processing Record 13 of Set 27 | korenovsk
# Processing Record 14 of Set 27 | evensk
# Processing Record 15 of Set 27 | ixtapa
# Processing Record 16 of Set 27 | melilla
# Processing Record 17 of Set 27 | sindor
# Processing Record 18 of Set 27 | darnah
# Processing Record 19 of Set 27 | syamzha
# Processing Record 20 of Set 27 | clonakilty
# Processing Record 21 of Set 27 | dhidhdhoo
# Processing Record 22 of Set 27 | banyo
# Processing Record 23 of Set 27 | dolbeau
# City not found. Skipping...
# Processing Record 24 of Set 27 | bowen
# Processing Record 25 of Set 27 | hervey bay
# Processing Record 26 of Set 27 | chulym
# Processing Record 27 of Set 27 | westport
# Processing Record 28 of Set 27 | batagay-alyta
# Processing Record 29 of Set 27 | muros
# Processing Record 30 of Set 27 | turrialba
# Processing Record 31 of Set 27 | san cristobal
# Processing Record 32 of Set 27 | caravelas
# Processing Record 33 of Set 27 | yulara
# Processing Record 34 of Set 27 | belaya gora
# Processing Record 35 of Set 27 | north bend
# Processing Record 36 of Set 27 | pedasi
# Processing Record 37 of Set 27 | rio gallegos
# Processing Record 38 of Set 27 | bandarbeyla
# Processing Record 39 of Set 27 | carutapera
# Processing Record 40 of Set 27 | rundu
# Processing Record 41 of Set 27 | merced
# Processing Record 42 of Set 27 | iwaki
# Processing Record 43 of Set 27 | padang
# Processing Record 44 of Set 27 | vestmannaeyjar
# Processing Record 45 of Set 27 | felidhoo
# City not found. Skipping...
# Processing Record 46 of Set 27 | fuxin
# Processing Record 47 of Set 27 | khash
# Processing Record 48 of Set 27 | hastings
# Processing Record 49 of Set 27 | abalak
# Processing Record 50 of Set 27 | chagda
# City not found. Skipping...
# -------------------------------------------------------
#  Waiting for 60 sec....
# -------------------------------------------------------
# Processing Record 1 of Set 28 | palabuhanratu
# City not found. Skipping...
# Processing Record 2 of Set 28 | guaratinga
# Processing Record 3 of Set 28 | thinadhoo
# Processing Record 4 of Set 28 | tekirdag
# Processing Record 5 of Set 28 | zhigansk
# Processing Record 6 of Set 28 | bukachacha
# Processing Record 7 of Set 28 | manggar
# Processing Record 8 of Set 28 | pospelikha
# Processing Record 9 of Set 28 | macomb
# Processing Record 10 of Set 28 | pochutla
# Processing Record 11 of Set 28 | jinotega
# Processing Record 12 of Set 28 | piraquara
# Processing Record 13 of Set 28 | sexsmith
# Processing Record 14 of Set 28 | port blair
# Processing Record 15 of Set 28 | yokadouma
# Processing Record 16 of Set 28 | pevek
# Processing Record 17 of Set 28 | coffs harbour
# Processing Record 18 of Set 28 | monte alegre
# Processing Record 19 of Set 28 | bargal
# City not found. Skipping...
# Processing Record 20 of Set 28 | sarkhej
# Processing Record 21 of Set 28 | ondangwa
# Processing Record 22 of Set 28 | veraval
# Processing Record 23 of Set 28 | solovetskiy
# City not found. Skipping...
# Processing Record 24 of Set 28 | poum
# Processing Record 25 of Set 28 | beringovskiy
# Processing Record 26 of Set 28 | filadelfia
# Processing Record 27 of Set 28 | sidney
# Processing Record 28 of Set 28 | talcahuano
# Processing Record 29 of Set 28 | newcastle
# Processing Record 30 of Set 28 | nouadhibou
# Processing Record 31 of Set 28 | straumen
# Processing Record 32 of Set 28 | barabinsk
# Processing Record 33 of Set 28 | ronne
# Processing Record 34 of Set 28 | nhulunbuy
# Processing Record 35 of Set 28 | ridgecrest
# Processing Record 36 of Set 28 | salalah
# Processing Record 37 of Set 28 | marcona
# City not found. Skipping...
# Processing Record 38 of Set 28 | nova vicosa
# Processing Record 39 of Set 28 | cuamba
# Processing Record 40 of Set 28 | atambua
# Processing Record 41 of Set 28 | ravar
# Processing Record 42 of Set 28 | shakawe
# Processing Record 43 of Set 28 | cedar city
# Processing Record 44 of Set 28 | miraflores
# Processing Record 45 of Set 28 | takoradi
# Processing Record 46 of Set 28 | inta
# Processing Record 47 of Set 28 | puerto madryn
# Processing Record 48 of Set 28 | bannawag
# City not found. Skipping...
# Processing Record 49 of Set 28 | wakefield
# Processing Record 50 of Set 28 | matara
# -------------------------------------------------------
#  Waiting for 60 sec....
# -------------------------------------------------------
# Processing Record 1 of Set 29 | atbasar
# Processing Record 2 of Set 29 | alihe
# Processing Record 3 of Set 29 | pemberton
# Processing Record 4 of Set 29 | teeli
# Processing Record 5 of Set 29 | port hedland
# Processing Record 6 of Set 29 | luanda
# Processing Record 7 of Set 29 | balingasay
# Processing Record 8 of Set 29 | taoudenni
# Processing Record 9 of Set 29 | corner brook
# Processing Record 10 of Set 29 | malkapur
# Processing Record 11 of Set 29 | belyy yar
# Processing Record 12 of Set 29 | tazirkah
# City not found. Skipping...
# Processing Record 13 of Set 29 | oka
# Processing Record 14 of Set 29 | vila franca do campo
# Processing Record 15 of Set 29 | oussouye
# Processing Record 16 of Set 29 | iracoubo
# Processing Record 17 of Set 29 | tocopilla
# Processing Record 18 of Set 29 | andenes
# Processing Record 19 of Set 29 | shubarkuduk
# Processing Record 20 of Set 29 | hearst
# Processing Record 21 of Set 29 | esfarayen
# Processing Record 22 of Set 29 | riaba
# City not found. Skipping...
# Processing Record 23 of Set 29 | kupang
# Processing Record 24 of Set 29 | fairbanks
# Processing Record 25 of Set 29 | kachiry
# Processing Record 26 of Set 29 | zarubino
# Processing Record 27 of Set 29 | erkrath
# Processing Record 28 of Set 29 | giresun
# Processing Record 29 of Set 29 | ratnapura
# Processing Record 30 of Set 29 | arman
# Processing Record 31 of Set 29 | harnosand
# Processing Record 32 of Set 29 | soubre
# Processing Record 33 of Set 29 | pouembout
# Processing Record 34 of Set 29 | manaus
# Processing Record 35 of Set 29 | dunmore east
# Processing Record 36 of Set 29 | kavaratti
# Processing Record 37 of Set 29 | maceio
# Processing Record 38 of Set 29 | punta de piedra
# Processing Record 39 of Set 29 | berlevag
# Processing Record 40 of Set 29 | iranshahr
# Processing Record 41 of Set 29 | nizhniy tsasuchey
# Processing Record 42 of Set 29 | baraya
# Processing Record 43 of Set 29 | fuyang
# Processing Record 44 of Set 29 | labutta
# City not found. Skipping...
# Processing Record 45 of Set 29 | noumea
# Processing Record 46 of Set 29 | nome
# Processing Record 47 of Set 29 | beira
# Processing Record 48 of Set 29 | ialibu
# Processing Record 49 of Set 29 | yuancheng
# Processing Record 50 of Set 29 | aleksandrovskiy zavod
# -------------------------------------------------------
#  Waiting for 60 sec....
# -------------------------------------------------------
# Processing Record 1 of Set 30 | cururupu
# Processing Record 2 of Set 30 | maniitsoq
# Processing Record 3 of Set 30 | vondrozo
# Processing Record 4 of Set 30 | sterling
# Processing Record 5 of Set 30 | rosetta
# Processing Record 6 of Set 30 | sumbawa
# City not found. Skipping...
# Processing Record 7 of Set 30 | vitim
# Processing Record 8 of Set 30 | mareeba
# Processing Record 9 of Set 30 | sansai
# City not found. Skipping...
# Processing Record 10 of Set 30 | leshukonskoye
# Processing Record 11 of Set 30 | beeville
# Processing Record 12 of Set 30 | sarkand
# Processing Record 13 of Set 30 | cochrane
# Processing Record 14 of Set 30 | xapuri
# Processing Record 15 of Set 30 | mayumba
# Processing Record 16 of Set 30 | lavrentiya
# Processing Record 17 of Set 30 | gasa
# Processing Record 18 of Set 30 | lata
# Processing Record 19 of Set 30 | malabo
# Processing Record 20 of Set 30 | melo
# Processing Record 21 of Set 30 | acari
# Processing Record 22 of Set 30 | gambiran
# Processing Record 23 of Set 30 | kuusamo
# Processing Record 24 of Set 30 | tahlequah
# Processing Record 25 of Set 30 | altay
# Processing Record 26 of Set 30 | la paz
# Processing Record 27 of Set 30 | midland
# Processing Record 28 of Set 30 | dublyany
# Processing Record 29 of Set 30 | yamada
# Processing Record 30 of Set 30 | uruzgan
# Processing Record 31 of Set 30 | lerwick
# Processing Record 32 of Set 30 | alappuzha
# Processing Record 33 of Set 30 | fereydun kenar
# Processing Record 34 of Set 30 | omsukchan
# Processing Record 35 of Set 30 | fort nelson
# Processing Record 36 of Set 30 | lasa
# Processing Record 37 of Set 30 | izhma
# Processing Record 38 of Set 30 | madimba
# Processing Record 39 of Set 30 | vestmanna
# Processing Record 40 of Set 30 | faanui
# Processing Record 41 of Set 30 | binzhou
# Processing Record 42 of Set 30 | haileybury
# Processing Record 43 of Set 30 | palpa
# Processing Record 44 of Set 30 | kenai
# Processing Record 45 of Set 30 | aktash
# Processing Record 46 of Set 30 | kamenka
# Processing Record 47 of Set 30 | aban
# Processing Record 48 of Set 30 | bilma
# Processing Record 49 of Set 30 | roma
# Processing Record 50 of Set 30 | sao filipe
# -------------------------------------------------------
#  Waiting for 60 sec....
# -------------------------------------------------------
# Processing Record 1 of Set 31 | ternate
# Processing Record 2 of Set 31 | oakdale
# Processing Record 3 of Set 31 | sarh
# Processing Record 4 of Set 31 | fredericton
# Processing Record 5 of Set 31 | dubbo
# Processing Record 6 of Set 31 | pontianak
# Processing Record 7 of Set 31 | holme
# Processing Record 8 of Set 31 | totocuitlapilco
# Processing Record 9 of Set 31 | rio tercero
# Processing Record 10 of Set 31 | grenfell
# Processing Record 11 of Set 31 | gamba
# Processing Record 12 of Set 31 | yumen
# Processing Record 13 of Set 31 | mutsu
# Processing Record 14 of Set 31 | kapit
# Processing Record 15 of Set 31 | mizdah
# Processing Record 16 of Set 31 | thaton
# Processing Record 17 of Set 31 | eldorado
# Processing Record 18 of Set 31 | christchurch
# Processing Record 19 of Set 31 | mrkonjic grad
# Processing Record 20 of Set 31 | mbanza-ngungu
# Processing Record 21 of Set 31 | borisovka
# Processing Record 22 of Set 31 | harku
# Processing Record 23 of Set 31 | healesville
# Processing Record 24 of Set 31 | najran
# Processing Record 25 of Set 31 | guerrero negro
# Processing Record 26 of Set 31 | ushtobe
# Processing Record 27 of Set 31 | voroshnevo
# Processing Record 28 of Set 31 | lazaro cardenas
# Processing Record 29 of Set 31 | dingle
# Processing Record 30 of Set 31 | galiwinku
# City not found. Skipping...
# Processing Record 31 of Set 31 | lodja
# Processing Record 32 of Set 31 | marrakesh
# Processing Record 33 of Set 31 | el cope
# Processing Record 34 of Set 31 | kidal
# Processing Record 35 of Set 31 | harlingen
# Processing Record 36 of Set 31 | wilmington
# Processing Record 37 of Set 31 | fergus falls
# Processing Record 38 of Set 31 | port macquarie
# Processing Record 39 of Set 31 | piacabucu
# Processing Record 40 of Set 31 | amberley
# Processing Record 41 of Set 31 | sembakung
# Processing Record 42 of Set 31 | kedrovyy
# Processing Record 43 of Set 31 | ayorou
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Total number of cities pulled from the API: 731

# %%
# Step 7. Add the data to a new DataFrame. 
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Norman Wells  65.2820 -126.8329     77.04        36          20
# 1      Hermanus -34.4187   19.2345     60.10        67           1
# 2    Butaritari   3.0707  172.7902     82.29        78          90
# 3      Sabzevar  36.2126   57.6819     83.48        23           0
# 4     Grindavik  63.8424  -22.4338     49.95        93         100
# 5        Narsaq  60.9167  -46.0500     53.82        74          20
# 6         Pisco -13.7000  -76.2167     63.01        82           0
# 7       Leirvik  59.7798    5.5005     60.62        92         100
# 8    Shellbrook  53.2168 -106.4011     52.83        91         100
# 9     Bathsheba  13.2167  -59.5167     83.01        78          75
#
#    Wind Speed Weather Description
# 0        8.05          few clouds
# 1       10.25           clear sky
# 2       15.79     overcast clouds
# 3       13.80           clear sky
# 4       10.36     overcast clouds
# 5        5.53          few clouds
# 6        8.05           clear sky
# 7       11.48       moderate rain
# 8        2.84          light rain
# 9       18.41       broken clouds

# %%
# Step 8. Export the DataFrame as a CSV file, and save it as WeatherPy_Database.csv in the Weather_Database folder.
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"

# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
